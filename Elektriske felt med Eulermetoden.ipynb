# %% [markdown]
# # Elektriske felt og Eulermetoden
# ---
# Velkommen til en Jupyter-notebook.
# Boka inneholder såkalte kode-celler, som har litt ferdig kode i seg, som du må fullføre.
# Du kan kjøre koden i en bestemt celle ved å sette musepekeren i en celle og så trykke på "play"-knappen i toppmenyen.
#
# ---
#
# ## Oppgave 1
#
# Hva er Eulermetoden, og hva er hovedidéen bak den når vi simulerer bevegelse?
#
# ## Oppgave 2
#
# Skriv ned Newtons 2. lov og uttrykket for kraften på en ladning i et elektrisk felt.
#
# ## Oppgave 3
#
# Forklar når vi må bruke numeriske metoder som Euler for å simulere bevegelse i et elektrisk felt.
#
# ## Oppgave 4
# Beskriv hvordan tidssteget $\Delta t$ påvirker nøyaktigheten i en Eulersimulering. Hva skjer hvis vi velger et for stort tidssteg?
#
# ## Oppgave 5
# Et elektron ($q = -1,6 \cdot 10^{-19} \text{ C}$, $m = 9,11 \cdot 10^{-31} \text{ kg}$) starter fra ro i et homogent elektrisk felt $E = 1000 \text{ N/C}$.
# #### a)
# Finn et uttrykk for elektronets akselerasjon i det elektriske feltet.
#
# #### b)
# Regn ut for hånd hva elektronets fart og posisjon er etter $10^{-9}$ sekunder.
#
# #### c)
# Fullfør programmet under for å beregne det samme med Eulermetoden:

# %%
# Konstanter:
q = 1.6E-19 # C
m = 9.11E-31 # kg
E = 1000 # N/C
dt = 1E-11 # s

# Startverdier:
t = 0
v = 0
s = 0

while t < 1E-9:
    # TODO: regn ut med Eulermetoden:
    a = 
    v = 
    s = 
    t = 

print(f"Farten blir {v} m/s og posisjonen blir {s} m")

# %% [markdown]
# ## Oppgave 6
#
# #### a)
# Endre Python-programmet slik at det lagrer posisjon og hastighet i lister og lager et plott av fart som funksjon av tid.

# %%
import matplotlib.pyplot as plt
# Konstanter:
q = 1.6E-19 # C
m = 9.11E-31 # kg
E = 1000 # N/C
dt = 1E-11 # s

# Startverdier:
t = 0
v = 0
s = 0

# Lister til lagring og plotting:
T = [t]
V = [v]
S = [s]

while t < 1E-9:
    # TODO: regn ut med Eulermetoden:
    a = 
    v = 
    s = 
    t = 

    # Legger til i listene:
    V.append(v)
    S.append(s)
    T.append(t)

# TODO: Fyll ut det som mangler for å tegne grafene:
plt.plot()
plt.xlabel()
plt.ylabel()
plt.show()
plt.plot()
plt.xlabel()
plt.ylabel()
plt.show()

# %% [markdown]
# #### b)
# Analyser grafen: Hvordan ser bevegelsen ut? Stemmer den med forventningene fra teorien?

# %% [markdown]
# #### c)
# Kjør simuleringen med to ulike tidssteg, $\Delta t = 10^{-11}\text{ s}$ og $\Delta t = 10^{-10} \text{ s}$.
# Sammenlign resultatene og diskuter hvordan tidssteg påvirker resultatet.
#
# ## Oppgave 7
# Utvid programmet til å simulere bevegelse i et inhomogent elektrisk felt rundt en punktladning med ladning $Q = -2,0\cdot 10^{-9} \text{ C}$. Anta at elektronet starter i ro 2 mm fra Q.
# Hvordan må du endre koden for å beregne akselerasjonen i hvert steg?

# %%
# TODO: Skriv det nye programmet ditt her

# %% [markdown]
# ## Oppgave 8
#
# Lag en simulering der en ladning beveger seg mellom to parallelle plater med et homogent felt, men med en startvinkel (ikke bare langs feltet).
# Visualiser banen i et 2D-plott (y som funksjon av x).

# %%
# TODO: Skriv det nye programmet ditt her
